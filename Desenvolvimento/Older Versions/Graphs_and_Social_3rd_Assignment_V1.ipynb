# %% [markdown]
# #1. Import de Bibliotecas:

# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# #2. Desenvolvimento do Trabalho:

# %% [markdown]
# ##2.1. Análise Geral

# %% [markdown]
# ###2.1.1. Gerar Grafos (Barabasi-Albert, Watts-Strogatz, e Erdös-Renyi)

# %%
Grafo_A = nx.barabasi_albert_graph(50, 5, seed = 24003315)
nx.draw(Grafo_A, with_labels = True, font_weight = 'bold')
plt.show()

# %%
Grafo_B = nx.watts_strogatz_graph(100, 5, 0.5, seed = 24002125)
nx.draw(Grafo_B, with_labels = True, font_weight = 'bold')
plt.show()

# %%
Grafo_C = nx.erdos_renyi_graph(50, 5, seed = 23027619, directed = False)
nx.draw(Grafo_C, with_labels = True, font_weight = 'bold')
plt.show()

# %% [markdown]
# ##2.2. Comparação com Grafo

# %% [markdown]
# ###2.2.1. Selecionar Grafos de uma base existente

# %% [markdown]
# #3. Resultado:

# %% [markdown]
# ##3.1. Parte 1 (Análise Geral)

# %% [markdown]
# ##3.2. Parte 2 (Comparação com Grafo)
